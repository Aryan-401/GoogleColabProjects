# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryan-401/GoogleColabProjects/blob/main/Shakespeare_Type_Generation_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import string
import random
import sys
# !pip install Unidecode
import unidecode
from torchtext.utils import download_from_url
from torch.utils.tensorboard import SummaryWriter

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
all_characters = string.printable
n_characters = len(all_characters)
print(all_characters, n_characters)
# Out:
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#  100

# %%
download_from_url('https://raw.githubusercontent.com/aladdinpersson/Machine-Learning-Collection/master/ML/Projects/text_generation_babynames/data/names.txt', './names.txt')
file_name = unidecode.unidecode(open('./names.txt').read())

# %%
file_path = download_from_url('https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt', './shakespeare.txt')
file_shakespeare = unidecode.unidecode(open('./shakespeare.txt').read())

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.embed = nn.Embedding(input_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first = True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden, cell):
        out = self.embed(x)
        out, (hidden, cell)  = self.lstm(out.unsqueeze(1), (hidden, cell))
        out = self.fc(out.reshape(out.shape[0], -1))
        return out, (hidden, cell)

    def init_hidden(self, batch_size):
        hidden = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(device)
        cell = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(device)
        return hidden, cell

# %%
class Generator():
    def __init__(self):
        self.chunk_len = 250
        self.num_epochs = 5000
        self.batch_size = 1
        self.print_every = 50
        self.hidden_size = 256
        self.num_layers = 2
        self.file = file_shakespeare
        self.lr = 0.003

    def char_tensor(self, string):
        tensor = torch.zeros(len(string)).long()
        for c in range(len(string)):
            tensor[c] = all_characters.index(string[c])
        return tensor

    def get_random_batch(self):
        start_index = random.randint(0, len(self.file) - self.chunk_len)
        end_index = start_index + self.chunk_len + 1
        text_str = self.file[start_index: end_index]
        text_input = torch.zeros(self.batch_size, self.chunk_len)
        text_target = torch.zeros(self.batch_size, self.chunk_len)

        for i in range(self.batch_size):
            text_input[i,:] = self.char_tensor(text_str[:-1])
            text_target[i,:] = self.char_tensor(text_str[1:])

        return text_input.long(), text_target.long()

    def generate(self, initial_string = 'A', prediction_len = 100, temprature = 1.0):
        hidden, cell = self.rnn.init_hidden(batch_size=self.batch_size)
        initial_input = self.char_tensor(initial_string)
        predicted = initial_string

        for p in range(len(initial_string) - 1):
            _, (hidden, cell) = self.rnn(initial_input[p].view(1).to(device), hidden, cell)

        last_char = initial_input[-1]

        for p in range(prediction_len):
            output, (hidden, cell) = self.rnn(last_char.view(1).to(device), hidden, cell)
            output_dist = output.data.view(-1).div(temprature).exp()
            top_char = torch.multinomial(output_dist, 1)[0]
            predicted_char = all_characters[top_char]
            predicted += predicted_char
            last_char = self.char_tensor(predicted_char)

        return predicted


    def train(self):
        self.rnn = RNN(n_characters, self.hidden_size, self.num_layers, n_characters).to(device)
        optimizer = torch.optim.Adam(self.rnn.parameters(), lr = self.lr)
        criterion = nn.CrossEntropyLoss()
        writer = SummaryWriter(f'runs/names0')

        print("== Starting Training ==")
        for epoch in range(1, self.num_epochs + 1):
            inp, target = self.get_random_batch()
            hidden, cell = self.rnn.init_hidden(batch_size=self.batch_size)

            self.rnn.zero_grad()
            loss = 0
            inp, target = inp.to(device), target.to(device)
            for c in range(self.chunk_len):
                output, (hidden, cell) = self.rnn(inp[:, c], hidden, cell)
                loss += criterion(output, target[:, c])

            loss.backward()
            optimizer.step()
            loss = loss.item() / self.chunk_len

            if epoch % self.print_every == 0:
                print(f"Epoch: {epoch}/ {self.num_epochs}| Loss: {loss}")
                print(self.generate())

            writer.add_scalar("Training loss", loss, global_step=epoch)

        torch.save(self.rnn.state_dict(), './shakespeare_model.pt')

# %%
gennames = Generator()
gennames.train()
# Out:
# == Starting Training ==
# Epoch: 50/ 5000| Loss: 2.544498291015625
# Aty g!ado- ay ILrureconvt aath yot aianthe.
# Av; hid;
# Thopen sire,
# Snoour
#
# : ort'e tande:
# Tsid mod rav
# Epoch: 100/ 5000| Loss: 2.31101123046875
# A
#
# Lsesthit't whreraxtash Ging!iy heamer.
#
# DEE
# AONDPNIA
# CAA:
# Pror what
# Yur ist aer shat ant yorithe s
# Epoch: 150/ 5000| Loss: 2.285608154296875
# Ar
# PGrapceavis
# yy sord
# Cit win the ny depondise
# Lord,
#
# UTENER:
# Ik itech treninok,.
#
# KTIY :nee humme
# T
# Epoch: 200/ 5000| Loss: 2.122548583984375
# AN:
# Pxat, will wey tordls tind shere
# Hom nell: no, aste reat be no dile. I till nofs.
#
# ANELBANE ECEK:
# Epoch: 250/ 5000| Loss: 2.068232666015625
# Ard, Iseld in igfheldundsty, grows heard.
#
# ORCAMRVHEUNDUO:
# Ed I doy myould
# Hereld ming, bow snise fer
# Epoch: 300/ 5000| Loss: 2.10134423828125
# Arcoye so lirstels Hame handluy anmeren'; sumtsenang wormtadings
# All dith, obseny
# desed to micher, me
# Epoch: 350/ 5000| Loss: 1.8351971435546874
# AND IEE deep?
#
# OL'TI:
# Thiser, and shat not frontas it Sing not jared as paling oncean in tint are Jin
# Epoch: 400/ 5000| Loss: 2.0220897216796874
# ATE
# CICENSins ande's; that,
# Bayd hing is dedayfo pasel anthigeed it ave in mowets
# And the fre horson,
# Epoch: 450/ 5000| Loss: 1.891758544921875
# A LORG:
# Sme zjuty, noung geet
# dare
# Whe ponting!
# Nor,
# The I sedst the from!
#
# SFurswonce, in sore with
# Epoch: 500/ 5000| Loss: 1.9148306884765625
# A<And:
# How'gher ages of heard frother to be riy bould, your heandy to speladge.
#
# KIGS:
# Alter heradfor
# Epoch: 550/ 5000| Loss: 1.8065079345703126
# Arden be whratter, trohser.
#
# GRATIUCE:
# It sin evence; witend I prebtione sented.
#
# RUCHIO:
# Blayiver'd
# Epoch: 600/ 5000| Loss: 1.9649432373046876
# ARASK:
# Nwe, have in of seep
# Hall, plefords willing the lovent! thathing let u waln?
#
# Norb, buts gict
# Epoch: 650/ 5000| Loss: 1.7292381591796875
# A
# If your a rithe to anry thy come,
# Yeml! that wo, wry, My grue.
#
# DUHLET:
# Will thou, af you duck.
#
# PE
# Epoch: 700/ 5000| Loss: 1.80026318359375
# ARD ELOLEF IV:
# Was will Bulanest, moster shasts, haves, the Evess you prriremprice:
# My
# Four theet oul
# Epoch: 750/ 5000| Loss: 1.758932861328125
# ART:
# Birle instured More back, peather
# Nait.
#
# SAND:
# By pate; fair the the
# wice she Eldove not dain sh
# Epoch: 800/ 5000| Loss: 1.83036083984375
# Ad wilts, Edst you goks in not loves not him mean not flather.
#
# BILILA:
# My apprars, man,
# And famen, t
# Epoch: 850/ 5000| Loss: 1.7525625
# Arist, will
# Thackse.
#
# Frois I rewest our thut bigile,
# Yo, an saysence: Ifforts
# This igpion!
#
# CIMIR:
# S
# Epoch: 900/ 5000| Loss: 1.841845458984375
# And bisur. And lill hole
# Themwimblogges the piert:
# And him was I and sing see wife are!
#
# For some is
# Epoch: 950/ 5000| Loss: 1.8107506103515625
# As sir'd but it.
#
# ADIALY:
# Why,
#
# ROCCETKE:
# Salling bit. If Py most leath,
# Terefork are revilegue'th fe
# Epoch: 1000/ 5000| Loss: 1.9008961181640625
# AMNE:
# The with that and that is the pard to eid like with be yifels, bong she roied.
#
# Secock toment;
# Epoch: 1050/ 5000| Loss: 2.000439208984375
# A
# So: tales somoy that that me a gock trank, wellio.
#
# AUTO:
# Wevere see vevence,
# Who recon
# Here croed
# Epoch: 1100/ 5000| Loss: 1.8108536376953126
# Able, Had his more,
# And so dies.
#
# BEMIANIS:
# Dot:
# Now, the
# tain of the sirofure his advely o is yillo
# Epoch: 1150/ 5000| Loss: 1.7324239501953125
# AMGBROKE:
# I' the dea boing.
#
# LETHUS:
# One the his age of m wits! My maur death her mited witis are Car
# Epoch: 1200/ 5000| Loss: 1.856921875
# A to than sun, rodomparriends fried breich is her hy shold,
# That?
#
# LICABEH, Merchiopong morefursare,
#
# Epoch: 1250/ 5000| Loss: 1.7181986083984375
# AREN:
# The arit, bontath unless:
# Have earthal, loitume heast durd,' sir,' this old creaffest to this
# G
# Epoch: 1300/ 5000| Loss: 1.5923848876953124
# AEd:
# Their itstans,
# !o; sir.
# DUKE VINCENTIO:
# Your with abest say,
# Why consend of rapsed, forby?
# Cene
# Epoch: 1350/ 5000| Loss: 1.60677978515625
# Awwy, Duth pooner berest so cousil'd's rougue to much o, back;
# They prised that, hus, farthou
# Whose -
# Epoch: 1400/ 5000| Loss: 2.0020457763671873
# AXE:
# But apistuard live is and thee.
# Why, at they Rome; rease;
# Notloy obes, strapate
# ISourny's come o
# Epoch: 1450/ 5000| Loss: 1.789188232421875
# A:
# Vilet love, for in alem;
# And joy; desty-the speak--
# Tyart weech forcely.
#
# MARIANA:
# A way, Aning ri
# Epoch: 1500/ 5000| Loss: 1.80677734375
# ANDE:
# Sho be, Karrived gied;
# Coint day: what I bake euture king.
# Clange to ever poter from I he way g
# Epoch: 1550/ 5000| Loss: 1.7902774658203124
# AE, sust now at that bitter drewing.
# You but and creak.
#
# ROMEO:
# Which upon law cathy musborthy, I hen
# Epoch: 1600/ 5000| Loss: 1.5440513916015626
# And his welrous tweetherelives.
# Ghis is lings outers:
#
# PRISTA:
# The mil is Edward I am her.
#
# BUCHEST:
#
# Epoch: 1650/ 5000| Loss: 1.6631224365234376
# A you his less. Nurth in opert.
#
# PETRUCHIO:
# And it as tale, matores me, I'rry hild.
#
# DOSERLAND:
# Now,
# Epoch: 1700/ 5000| Loss: 1.44795068359375
# And the shilld becounted, net on wencting day fool'd the wand,
# My thou foul not had so kind, noble ll
# Epoch: 1750/ 5000| Loss: 1.275362548828125
# ANGERS:
# Pressing contend ut Henrarug's lore was.
#
# KING RICHARD IV:
# Good grace lood, fear have heand
# A
# Epoch: 1800/ 5000| Loss: 1.600972900390625
# Andern, nok was id fagetas would. But munes
# broriest to-meach shall d wnom and blly
# But day this pale
# Epoch: 1850/ 5000| Loss: 1.59301416015625
# A:
# Foull joy, Katter they him past of thy destrain him let trick and heaven me; hathle Suft
# my draw d
# Epoch: 1900/ 5000| Loss: 1.459572021484375
# And to son put offer.
# Underefurt-will yourthand face or hands of his frease
# Him go so mance to hing g
# Epoch: 1950/ 5000| Loss: 1.6486104736328124
# Ard. O'en thou skinus loisent,
# But for then Your,' bay. well,
# To sup a not bid of killeds a
# vockers b
# Epoch: 2000/ 5000| Loss: 1.5314417724609375
# And compast:
# Fhat his sword, bushind. kight.
#
# DUKE VINCENTIO:
# He cich the wostant in put
# Till thee a
# Epoch: 2050/ 5000| Loss: 1.873376708984375
# A:
# It therefore their, knitred cofforget your cursed,
# That arien's herpond;'s come? Anguily mark:
# And
# Epoch: 2100/ 5000| Loss: 1.600806640625
# And your now.
#
# FRIANA:
# Hark you not to the pray Ky at's do colent
# Of parreal or Mause, a let knishs i
# Epoch: 2150/ 5000| Loss: 1.5833236083984374
# A: God on
# Thou prafe in over ander and back'd party the resun:
# Sties and sword huw channews to caperi
# Epoch: 2200/ 5000| Loss: 1.62531640625
# Acds meast,
# My priped it to much brother
# apot soul, for made and fay you shall did
# Of thoughtering of
# Epoch: 2250/ 5000| Loss: 1.6219854736328125
# Ald which a smerk
# warrious, I'll neschild better to the frim.
#
# DUCHUSTENSIO:
# This griest her: pirvon
#
# Epoch: 2300/ 5000| Loss: 1.42238916015625
# As by the same, a come bor o'er mirry twily:
# Of then I best Rome, do, who are, Ell.
#
# HENRY VI:
# Their
# Epoch: 2350/ 5000| Loss: 1.410994140625
# And is revenge, tickine,
# Come and by inblike for merce, day them.
#
# KATHARINGS:
# I must Ond it up death
# Epoch: 2400/ 5000| Loss: 1.5386180419921875
# Acounter!
#
# KATHARI:
# What be grace and have be have shattive,
# Stay veath. I appitier of him'd him more
# Epoch: 2450/ 5000| Loss: 1.536902587890625
# A':
# Then, so Nollow't: I'll prebring and like,
# Let.' I peame so Clenour.
#
# POMIREM:
# Whict, in ther rec
# Epoch: 2500/ 5000| Loss: 1.5338134765625
# Aft,
# Our befores' dower the more ad favereway lords,
# Who loudard, are so joy,
# Come, bur will not that
# Epoch: 2550/ 5000| Loss: 1.6076083984375
# Ar:
# I becoup is the vear, well more, adod
# That a gots her whom, your hang them,
# The navoudish of bloo
# Epoch: 2600/ 5000| Loss: 1.618022216796875
# AS, when that fire
# That nurch as by, little like a but the park this cause.
#
# LUCIO:
# You we, with at I
# Epoch: 2650/ 5000| Loss: 1.4688946533203124
# ALY:
# That? for say, and sexolans and mine,
# Come enard forfold head worthling, contage, have in:
# At no
# Epoch: 2700/ 5000| Loss: 1.730753173828125
# And I mister to thee any execred,
# Is with your gods, there?
# Our sto miself a gazents,--are nor or for
# Epoch: 2750/ 5000| Loss: 1.475379638671875
# And what strike water: a then: the must me?
#
# MEMBALT:
# Ay, and be, there, Rimal triety; I'll lrough'd
#
# Epoch: 2800/ 5000| Loss: 1.6091060791015626
# ARDWAW:
# E fries Riscidue aburn.
# Whusk me both whose royssuppay follow.
# Luke, away be come, wounds, so
# Epoch: 2850/ 5000| Loss: 1.5583914794921876
# And yew I tray'd, talk's fathers
# of my tood my like where hand. What nobered sigea in
# Womening inspec
# Epoch: 2900/ 5000| Loss: 1.32735791015625
# And wet I, in,
# Sain: I'ld stage of hem like and
# dead, this should times veance, if I'll thy spetrex.
#
# Epoch: 2950/ 5000| Loss: 1.6587686767578125
# And the joices.
# Ah, good like helfor Cominatdes thee
# of gargethen thou camely,
# Well the moxe,
# I'll br
# Epoch: 3000/ 5000| Loss: 1.4165755615234374
# And it my suspide provoyan,
# Where you ars sistress, counffless, my break, that whilst,; seched too fe
# Epoch: 3050/ 5000| Loss: 1.6712962646484375
# APY:
# Will I will blose; and this, I lay which I litterd?
#
# First Gentlemp,
# But I to to my luck our blo
# Epoch: 3100/ 5000| Loss: 1.81556494140625
# Ard my sidst of all the wife.
#
# VISCUTIO:
# The ear and repose what is incher: bier capely.
#
# KING EDWARD
# Epoch: 3150/ 5000| Loss: 1.418452392578125
# A will and say.
#
# QUEEN MARGARET:
# Be Parmibove though with shall blise make bear of thy love, Juleal.
#
# Epoch: 3200/ 5000| Loss: 1.671932373046875
# A courson noble,
# And be wrank my Rom.
#
# MESSARENCE:
# Where wound by Clarens forfulty:
# And by thy counte
# Epoch: 3250/ 5000| Loss: 1.678876708984375
# And not much but.
#
# PETRUCHIO:
# He loss, now with him seace,
# And whom disgrong was ear mista:: God,
# The
# Epoch: 3300/ 5000| Loss: 1.633605224609375
# A mildrer:
# And ay, and Earl. But, and wheel'd break and greaced,
# With the waited my bire! and the yre
# Epoch: 3350/ 5000| Loss: 1.63004638671875
# Ard Sice thee him, to him, sed
# I was you she multain'd of him a looks.
# I will bed up it you nothing t
# Epoch: 3400/ 5000| Loss: 1.52067333984375
# ARIS:
# My thought nurthy his childed thy and olwarn;
# You entle gone, he may night. Where's
# knoke to th
# Epoch: 3450/ 5000| Loss: 1.3875595703125
# As.
#
# KING EDWARD IV:
# Most I was downed, doces? vear solady, and but I had royal to revizent,
# For for
# Epoch: 3500/ 5000| Loss: 1.6331600341796875
# ANGELO:
# 'Tis a follOw with that he capted
# 'Tis lust-unvendon for is this chambray for
# Shesh fool that
# Epoch: 3550/ 5000| Loss: 1.76810546875
# AD:
# I shall die, O good chambled, be I shem.
# Her degated with the her the hathin,
# Lose;
# To death; I t
# Epoch: 3600/ 5000| Loss: 1.50221484375
# ANGELO:
# Hour more is not her good that not mourt
# Adough a fake a filt state off they
# by height of Rom
# Epoch: 3650/ 5000| Loss: 1.6074459228515625
# ANIAN:
# Romeoo lew us are grace
# You are now you: that welfity! I have my affit to the handrect.
# If no
# Epoch: 3700/ 5000| Loss: 1.4969786376953125
# A:
# I'll smirswer himself sift help;
# For there coution air to chanch'd
# With thussalt bid for fratter a
# Epoch: 3750/ 5000| Loss: 1.691129638671875
# ARUHEN:
# Surllips, suppities; ke a madiemned
# to you, holy know she things the mar.
# That hasted tranig?
# Epoch: 3800/ 5000| Loss: 1.7055328369140625
# Arbazed
# Thee, but on myself joy to live,
# Whick on dost to shall menry;
# Whilithtay from the Racious fa
# Epoch: 3850/ 5000| Loss: 1.4101617431640625
# ARUM:
# Raw you murn very shall benced by our grant:
# The vains heaven and may counsence.
#
# Second hearts
# Epoch: 3900/ 5000| Loss: 1.354769287109375
# ANLETS:
# So wears hour tignouts; to your rest,
# And you master?
# Look of his good greed:
# I than that cau
# Epoch: 3950/ 5000| Loss: 1.4704075927734375
# AbUnT:
# Med, to knows whose ground, good you to subst?
#
# DUKINANE:
# A much of their fear our this roy:
# T
# Epoch: 4000/ 5000| Loss: 1.3802467041015625
# An this adder,
# I'll say his last bindle, if but Vort: tese thou
# cannot I incrupeding women,
# We'll, sh
# Epoch: 4050/ 5000| Loss: 1.48110498046875
# APURENBERLANDA:
# While!
# Well up.
#
# STCAKE:
# And man? Greed bloggether, the chilst's thine
# The-heor it sw
# Epoch: 4100/ 5000| Loss: 1.4576553955078124
# And and sweet come thy sling of thou had,
# as then no quout in that falfest thou
# thence statiGon so go
# Epoch: 4150/ 5000| Loss: 1.7150257568359375
# And Cmilloceful at weeper:
# Then entreater'd time.
#
# HORTENSIO:
# Sir,'' thee pest seek.
#
# ESCALUS:
# The di
# Epoch: 4200/ 5000| Loss: 1.566525390625
# AND:
# No, 'the came it matter's moots
# From extrike the remost bodd
# Will by she watchis clows fortune,
# Epoch: 4250/ 5000| Loss: 1.52295361328125
# ATH VING HENRY VI OF RICHARD:
# Paid, pregain; let's perfom to execupy:
# Sir of the waybury?
#
# LARNARDINE
# Epoch: 4300/ 5000| Loss: 1.5898812255859376
# And the Vime one lies;
# When we into by you changed vileing inllow
# And crayer'd sorrow we walt ating?
#
# Epoch: 4350/ 5000| Loss: 1.5025438232421875
# Ard Clancaws are rebak; are ravishal,
# Call deam'd fease a worse lightly claw
# Wine a times so up; and
# Epoch: 4400/ 5000| Loss: 1.7092659912109376
# AnNone.
# O Gaiit
# Herefwell to his hour granie?
#
# POLOLIABUS:
#
# YORK:
# O, so seakingers, pronessimate,
# Let
# Epoch: 4450/ 5000| Loss: 1.2806910400390625
# Ar I'll intent what, on then so!
# was art it shall farewell not now you, where in thou
# death Ay, a lov
# Epoch: 4500/ 5000| Loss: 1.32656640625
# ANIO:
# Nor proud, we call mine yet, I make ruthrows shallones!
#
# PAULINA:
# It shame a waitilor soul.
#
# FR
# Epoch: 4550/ 5000| Loss: 1.4528045654296875
# Ance while: and they thou gods.
#
# AbOAP:
# Force, that Marcius? So night
# Became, too say are did his poo
# Epoch: 4600/ 5000| Loss: 1.5592861328125
# ANIO:
# I'll that within; let his as.
#
# FROTH:
# I bid: let's abrey falther than why Praid
# A rebeness my f
# Epoch: 4650/ 5000| Loss: 1.6227540283203126
# AN MARGARET:
# But 'Grops wear than those cale goose;
# And, but oven by the return light, I
# praw the res
# Epoch: 4700/ 5000| Loss: 1.516248291015625
# ANG IV:
# By notsen many, in a charm,
# Let in hither my maves stand, as thou
# well tell well so unate'ent
# Epoch: 4750/ 5000| Loss: 1.5856005859375
# ANn:
# What is loved terrorse mentice.
# Set he rand, Lrancus, You men me,
# Signig never grace, or begin s
# Epoch: 4800/ 5000| Loss: 1.2432996826171876
# An
# Voming up for my fixt be Cupulle me,
# And, as it yourself serves and hapene o'
# out down in were pai
# Epoch: 4850/ 5000| Loss: 1.485894775390625
# A
# My lamp let's foll! But suching seealed
# Thou true reoved me heaver gone,
# For yet her corrunt sworma
# Epoch: 4900/ 5000| Loss: 1.7082181396484375
# A
# Art Romeo and so hall.
# By callabity, for I weaknes: one follow?
#
# Back, wise your, musy lord,
# Or, yi
# Epoch: 4950/ 5000| Loss: 1.5637545166015625
# A you very to back.
#
# CORIOLANUS:
# I go. Farewell griet; way, so better.
#
# MENENIUS:
# Give me, piit here;
# Epoch: 5000/ 5000| Loss: 1.480269287109375
# And withal another.
#
# Provost:
# Have my lears, rambarst, and I houser thee.
# Comierful manioth stay; if

# %%
gennames.generate('Time to cry away my sorrows in wine ', 100, 0.4)
# Out:
# 'Time to cry away my sorrows in wine me a sance\nShall the great of the apperound the souls,\nAnd therefore will not fall and therefore han'
